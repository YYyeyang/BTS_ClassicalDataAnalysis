# %% [markdown]
# # Subject: Advanced Data Analysis
#
# # Module: Geospatial Analysis
#
# ## Session 1 - Address and Reverse Geocoding
#
# ### Demo 3 -  Geocoding

# %% [markdown]
# # 1. Geocode using single line addresses

# %%
from arcgis.gis import GIS
from arcgis.geocoding import get_geocoders, batch_geocode

gis = GIS("http://www.arcgis.com", "Gutierres_bts", "Liberdade3030")

# gis = GIS("http://www.arcgis.com", "username", "password")

# use the first of GIS's configured geocoders
geocoder = get_geocoders(gis)[0]

# %%
addresses = ["380 New York St, Redlands, CA", 
             "1 World Way, Los Angeles, CA",
             "1200 Getty Center Drive, Los Angeles, CA", 
             "5905 Wilshire Boulevard, Los Angeles, CA",
             "100 Universal City Plaza, Universal City, CA 91608",
             "4800 Oak Grove Dr, Pasadena, CA 91109"]

# %%
results = batch_geocode(addresses)

# %%
results
# Out:
# [{'address': '380 New York St, Redlands, California, 92373',
#   'attributes': {'AddBldg': '',
#    'AddNum': '380',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'PointAddress',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Redlands',
#    'Country': 'USA',
#    'DisplayX': -117.1953135,
#    'DisplayY': 34.05610800000001,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': '380 New York St, Redlands, CA, 92373, USA',
#    'Match_addr': '380 New York St, Redlands, California, 92373',
#    'MetroArea': 'Inland Empire',
#    'Nbrhd': 'West Redlands',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': '380 New York St, Redlands, California, 92373',
#    'Postal': '92373',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 0,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': '380 New York St',
#    'Side': 'R',
#    'StAddr': '380 New York St',
#    'StDir': '',
#    'StName': 'New York',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'St',
#    'Status': 'M',
#    'SubAddr': '',
#    'Subregion': 'San Bernardino County',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.1956703176181,
#    'Xmax': -117.19431349999999,
#    'Xmin': -117.1963135,
#    'Y': 34.05648811930892,
#    'Ymax': 34.05710800000001,
#    'Ymin': 34.05510800000001,
#    'Zone': ''},
#   'location': {'x': -117.19567031799994, 'y': 34.05648811900005},
#   'score': 100},
#  {'address': '1 World Way, Los Angeles, California, 90045',
#   'attributes': {'AddBldg': '',
#    'AddNum': '1',
#    'AddNumFrom': '1',
#    'AddNumTo': '99',
#    'AddRange': '1-99',
#    'Addr_type': 'StreetAddress',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Los Angeles',
#    'Country': 'USA',
#    'DisplayX': -118.39847141222306,
#    'DisplayY': 33.94432663265488,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': '1 World Way, Los Angeles, CA, 90045, USA',
#    'Match_addr': '1 World Way, Los Angeles, California, 90045',
#    'MetroArea': 'Los Angeles Metro Area',
#    'Nbrhd': 'Westchester',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': '1 World Way, Los Angeles, California, 90045',
#    'Postal': '90045',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 1,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': '1 World Way',
#    'Side': 'R',
#    'StAddr': '1 World Way',
#    'StDir': '',
#    'StName': 'World',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'Way',
#    'Status': 'M',
#    'SubAddr': '',
#    'Subregion': 'Los Angeles County',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -118.39847141222306,
#    'Xmax': -118.39747141222306,
#    'Xmin': -118.39947141222306,
#    'Y': 33.94432663265488,
#    'Ymax': 33.945326632654876,
#    'Ymin': 33.94332663265488,
#    'Zone': ''},
#   'location': {'x': -118.39847141199999, 'y': 33.94432663300006},
#   'score': 100},
#  {'address': '1200 Getty Center Dr, Los Angeles, California, 90049',
#   'attributes': {'AddBldg': '',
#    'AddNum': '1200',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'PointAddress',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Los Angeles',
#    'Country': 'USA',
#    'DisplayX': -118.4754015,
#    'DisplayY': 34.079831999999996,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': '1200 Getty Center Dr, Los Angeles, CA, 90049, USA',
#    'Match_addr': '1200 Getty Center Dr, Los Angeles, California, 90049',
#    'MetroArea': 'Los Angeles Metro Area',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': '1200 Getty Center Dr, Los Angeles, California, 90049',
#    'Postal': '90049',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 2,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': '1200 Getty Center Dr',
#    'Side': 'R',
#    'StAddr': '1200 Getty Center Dr',
#    'StDir': '',
#    'StName': 'Getty Center',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'Dr',
#    'Status': 'M',
#    'SubAddr': '',
#    'Subregion': 'Los Angeles County',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -118.47640204778182,
#    'Xmax': -118.4744015,
#    'Xmin': -118.47640150000001,
#    'Y': 34.088529314189906,
#    'Ymax': 34.080831999999994,
#    'Ymin': 34.078832,
#    'Zone': 'Brentwood'},
#   'location': {'x': -118.47640204799995, 'y': 34.08852931400003},
#   'score': 100},
#  {'address': '5905 Wilshire Blvd, Los Angeles, California, 90036',
#   'attributes': {'AddBldg': '',
#    'AddNum': '5905',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'PointAddress',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Los Angeles',
#    'Country': 'USA',
#    'DisplayX': -118.356894,
#    'DisplayY': 34.06371300000001,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': '5905 Wilshire Blvd, Los Angeles, CA, 90036, USA',
#    'Match_addr': '5905 Wilshire Blvd, Los Angeles, California, 90036',
#    'MetroArea': 'Los Angeles Metro Area',
#    'Nbrhd': 'Fairfax',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': '5905 Wilshire Blvd, Los Angeles, California, 90036',
#    'Postal': '90036',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 3,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': '5905 Wilshire Blvd',
#    'Side': 'R',
#    'StAddr': '5905 Wilshire Blvd',
#    'StDir': '',
#    'StName': 'Wilshire',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'Blvd',
#    'Status': 'M',
#    'SubAddr': '',
#    'Subregion': 'Los Angeles County',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -118.35881119271286,
#    'Xmax': -118.35589399999999,
#    'Xmin': -118.357894,
#    'Y': 34.06271035674239,
#    'Ymax': 34.064713000000005,
#    'Ymin': 34.06271300000001,
#    'Zone': ''},
#   'location': {'x': -118.35881119299995, 'y': 34.06271035700007},
#   'score': 100},
#  {'address': '100 Universal City Plz, Universal City, California, 91608',
#   'attributes': {'AddBldg': '',
#    'AddNum': '100',
#    'AddNumFrom': '136',
#    'AddNumTo': '46',
#    'AddRange': '46-136',
#    'Addr_type': 'StreetAddress',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Universal City',
#    'Country': 'USA',
#    'DisplayX': -118.35437820891575,
#    'DisplayY': 34.13616756783956,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': '100 Universal City Plz, Universal City, CA, 91608, USA',
#    'Match_addr': '100 Universal City Plz, Universal City, California, 91608',
#    'MetroArea': 'Los Angeles Metro Area',
#    'Nbrhd': 'Universal City',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': '100 Universal City Plz, Universal City, California, 91608',
#    'Postal': '91608',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 4,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': '100 Universal City Plz',
#    'Side': 'R',
#    'StAddr': '100 Universal City Plz',
#    'StDir': '',
#    'StName': 'Universal City',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'Plz',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Los Angeles County',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -118.35437820891575,
#    'Xmax': -118.35337820891574,
#    'Xmin': -118.35537820891575,
#    'Y': 34.13616756783956,
#    'Ymax': 34.137167567839555,
#    'Ymin': 34.13516756783956,
#    'Zone': ''},
#   'location': {'x': -118.35437820899995, 'y': 34.136167568000076},
#   'score': 100},
#  {'address': '4800 Oak Grove Dr, La Canada Flintridge, California, 91011',
#   'attributes': {'AddBldg': '',
#    'AddNum': '4800',
#    'AddNumFrom': '4724',
#    'AddNumTo': '4798',
#    'AddRange': '4724-4798',
#    'Addr_type': 'StreetAddressExt',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'La Canada Flintridge',
#    'Country': 'USA',
#    'DisplayX': -118.1752984817961,
#    'DisplayY': 34.19778672419795,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '91109',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': '4800 Oak Grove Dr, La Canada Flintridge, CA, 91011, USA',
#    'Match_addr': '4800 Oak Grove Dr, La Canada Flintridge, California, 91011',
#    'MetroArea': 'Los Angeles Metro Area',
#    'Nbrhd': 'City of Pasadena',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': '4800 Oak Grove Dr, La Canada Flintridge, California, 91011',
#    'Postal': '91011',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 5,
#    'Score': 87,
#    'Sector': '',
#    'ShortLabel': '4800 Oak Grove Dr',
#    'Side': 'R',
#    'StAddr': '4800 Oak Grove Dr',
#    'StDir': '',
#    'StName': 'Oak Grove',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'Dr',
#    'Status': 'M',
#    'SubAddr': '',
#    'Subregion': 'Los Angeles County',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -118.1752984817961,
#    'Xmax': -118.1742984817961,
#    'Xmin': -118.17629848179611,
#    'Y': 34.19778672419795,
#    'Ymax': 34.198786724197944,
#    'Ymin': 34.19678672419795,
#    'Zone': ''},
#   'location': {'x': -118.17529848199996, 'y': 34.197786724000025},
#   'score': 87}]

# %%
map = gis.map("Los Angeles", 9)
map

# %%
for address in results:
    map.draw(address['location'])

# %% [markdown]
# # 2. Geocode airport codes with category

# %%
airports = batch_geocode(["LAX", "SFO", "ONT", "FAT", "LGB"], category="airport")

# %%
airports
# Out:
# [{'address': 'LAX',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Los Angeles',
#    'Country': 'USA',
#    'DisplayX': -118.40896999999995,
#    'DisplayY': 33.94251000000003,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'LAX, Los Angeles, CA, USA',
#    'Match_addr': 'LAX',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'LAX',
#    'Place_addr': 'Los Angeles, California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 7,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 0,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'LAX',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Los Angeles County',
#    'Territory': '',
#    'Type': 'Airport',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -118.40896999999995,
#    'Xmax': -118.38396999999995,
#    'Xmin': -118.43396999999996,
#    'Y': 33.94251000000003,
#    'Ymax': 33.967510000000026,
#    'Ymin': 33.91751000000003,
#    'Zone': ''},
#   'location': {'x': -118.40896999999995, 'y': 33.94251000000003},
#   'score': 100},
#  {'address': 'SFO',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': '',
#    'Country': 'USA',
#    'DisplayX': -122.37579999999997,
#    'DisplayY': 37.61882000000003,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'SFO, CA, USA',
#    'Match_addr': 'SFO',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'SFO',
#    'Place_addr': 'California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 7,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 1,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'SFO',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Mateo County',
#    'Territory': '',
#    'Type': 'Airport',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -122.37579999999997,
#    'Xmax': -122.35079999999996,
#    'Xmin': -122.40079999999998,
#    'Y': 37.61882000000003,
#    'Ymax': 37.64382000000003,
#    'Ymin': 37.59382000000003,
#    'Zone': ''},
#   'location': {'x': -122.37579999999997, 'y': 37.61882000000003},
#   'score': 100},
#  {'address': 'ONT',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Ontario',
#    'Country': 'USA',
#    'DisplayX': -117.60199999999998,
#    'DisplayY': 34.055840000000046,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'ONT, Ontario, CA, USA',
#    'Match_addr': 'ONT',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'ONT',
#    'Place_addr': 'Ontario, California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 7,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 2,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'ONT',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Bernardino County',
#    'Territory': '',
#    'Type': 'Airport',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.60199999999998,
#    'Xmax': -117.57699999999997,
#    'Xmin': -117.62699999999998,
#    'Y': 34.055840000000046,
#    'Ymax': 34.080840000000045,
#    'Ymin': 34.03084000000005,
#    'Zone': ''},
#   'location': {'x': -117.60199999999998, 'y': 34.055840000000046},
#   'score': 100},
#  {'address': 'FAT',
#   'attributes': {'AddBldg': '',
#    'AddNum': '5175',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Fresno',
#    'Country': 'USA',
#    'DisplayX': -119.71927,
#    'DisplayY': 36.768970000000024,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'FAT, 5175 E Clinton Way, Fresno, CA, 93727, USA',
#    'Match_addr': 'FAT',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '(559) 621-4500',
#    'PlaceName': 'FAT',
#    'Place_addr': '5175 E Clinton Way, Fresno, California, 93727',
#    'Postal': '93727',
#    'PostalExt': '',
#    'Rank': 21,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 3,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'FAT',
#    'Side': 'L',
#    'StAddr': '5175 E Clinton Way',
#    'StDir': '',
#    'StName': 'Clinton',
#    'StPreDir': 'E',
#    'StPreType': '',
#    'StType': 'Way',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Fresno County',
#    'Territory': '',
#    'Type': 'Airport',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -119.71927,
#    'Xmax': -119.70127,
#    'Xmin': -119.73727,
#    'Y': 36.768970000000024,
#    'Ymax': 36.786970000000025,
#    'Ymin': 36.750970000000024,
#    'Zone': ''},
#   'location': {'x': -119.71927, 'y': 36.768970000000024},
#   'score': 100},
#  {'address': 'LGB',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Long Beach',
#    'Country': 'USA',
#    'DisplayX': -118.15229,
#    'DisplayY': 33.81752000000006,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'LGB, Long Beach, CA, USA',
#    'Match_addr': 'LGB',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'LGB',
#    'Place_addr': 'Long Beach, California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 7,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'ResultID': 4,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'LGB',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Los Angeles County',
#    'Territory': '',
#    'Type': 'Airport',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -118.15229,
#    'Xmax': -118.11228999999999,
#    'Xmin': -118.19229,
#    'Y': 33.81752000000006,
#    'Ymax': 33.85752000000006,
#    'Ymin': 33.77752000000006,
#    'Zone': ''},
#   'location': {'x': -118.15229, 'y': 33.81752000000006},
#   'score': 100}]

# %%
map = gis.map("CA", 2)
map

# %%
for airport in airports:
    popup = { 
    "title" : airport['attributes']['PlaceName'], 
    "content" : airport['address']
    }
    map.draw(airport['location'], popup)

# %% [markdown]
# ## Task: test the geocoding based on other address (e.g. your home, your city, BTS building).

# %%
myaddress = ["111 Carrer de Pujades, Barcelona, Spain"]

# %%
results = batch_geocode(myaddress)
results
# Out:
# [{'address': 'Carrer de Pujades 111, 08005, El Poblenou, Barcelona, Catalunya',
#   'attributes': {'AddBldg': '',
#    'AddNum': '111',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'PointAddress',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Barcelona',
#    'Country': 'ESP',
#    'DisplayX': 2.196629999999999,
#    'DisplayY': 41.39872199999999,
#    'Distance': 0,
#    'District': 'Barcelona',
#    'ExInfo': '',
#    'LangCode': 'CAT',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'Carrer de Pujades 111, 08005, El Poblenou, Barcelona, Catalunya, ESP',
#    'Match_addr': 'Carrer de Pujades 111, 08005, El Poblenou, Barcelona, Catalunya',
#    'MetroArea': '',
#    'Nbrhd': 'El Poblenou',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'Carrer de Pujades 111, 08005, El Poblenou, Barcelona, Catalunya',
#    'Postal': '08005',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'Catalunya',
#    'RegionAbbr': '',
#    'ResultID': 0,
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'Carrer de Pujades 111',
#    'Side': 'L',
#    'StAddr': 'Carrer de Pujades 111',
#    'StDir': '',
#    'StName': 'Pujades',
#    'StPreDir': '',
#    'StPreType': 'Carrer de',
#    'StType': '',
#    'Status': 'M',
#    'SubAddr': '',
#    'Subregion': 'Barcelona',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': 2.196691858445419,
#    'Xmax': 2.197629999999999,
#    'Xmin': 2.195629999999999,
#    'Y': 41.398685873997316,
#    'Ymax': 41.39972199999999,
#    'Ymin': 41.397721999999995,
#    'Zone': ''},
#   'location': {'x': 2.196691858000065, 'y': 41.39868587400008},
#   'score': 100}]

# %%
map = gis.map("Barcelona", 5)
map

# %%
for address in results:
    map.draw(address['location'])
